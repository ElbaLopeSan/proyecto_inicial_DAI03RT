# %%
# TRANSFORM

# %%
# Importar pandas y numpy
import pandas as pd
import numpy as np

# %%
# Cargar el csv
df = pd.read_csv("BillboardHot100.csv")
print(df.shape)
df.head()
# Out:
# (100, 14)
#    top                      track_name  track_popularity  duration_ms  \
# 0    1                        Ordinary                96       186964
# 1    2  What I Want (feat. Tate McRae)                75       184517
# 2    3                    Just In Case                83       166206
# 3    4              A Bar Song (Tipsy)                88       171291
# 4    5                 I'm The Problem                79       177811
#
#      artist_name artist_genres  artist_popularity       feats  explicit  \
# 0    Alex Warren           NaN                 90         NaN     False
# 1  Morgan Wallen       country                 95  Tate McRae     False
# 2  Morgan Wallen       country                 95         NaN     False
# 3      Shaboozey           NaN                 82         NaN      True
# 4  Morgan Wallen       country                 95         NaN     False
#
#                 album    type relase_date                track_id  \
# 0            Ordinary  single  2025-02-07  6qqrTXSdwiJaq8SO0X2lSe
# 1     I’m The Problem   album  2025-05-16  48NthgcgfoRrWT8LtgW28A
# 2        Just In Case  single  2025-03-21  02Ya2Q08bBKFqUJvjmyRXK
# 3  A Bar Song (Tipsy)  single  2024-04-12  2FQrifJ1N335Ljm3TjTVVf
# 4     I'm The Problem  single  2025-01-31  3HlWVKwU0JqJXqJK9DWHnZ
#
#                 artist_id
# 0  0fTSzq9jAh4c36UVb4V7CB
# 1  4oUHIQIBe0LHzYfvXNW4QM
# 2  4oUHIQIBe0LHzYfvXNW4QM
# 3  3y2cIKLjiOlp1Np37WiUdH
# 4  4oUHIQIBe0LHzYfvXNW4QM

# %%
# Cargar el csv
df = pd.read_csv("top_charts.csv")
print(df.shape)
df.head()
# Out:
# (374, 15)
#    top        track_name  track_popularity  duration_ms  artist_name  \
# 0    1  no tiene sentido                93       158036        Beéle
# 1    2          Ordinary                96       186964  Alex Warren
# 2    3      6 DE FEBRERO                75       175584       Aitana
# 3    4        blackout 🧊                84       182282       Emilia
# 4    5              APT.                94       169917         ROSÉ
#
#                           artist_genres  artist_popularity              feats  \
# 0  latin afrobeats|reggaeton|pop urbano                 93                NaN
# 1                                   NaN                 90                NaN
# 2                                   NaN                 80                NaN
# 3                        argentine trap                 80  TINI|Nicki Nicole
# 4                                 k-pop                 85         Bruno Mars
#
#    explicit         album    type relase_date                track_id  \
# 0     False       BORONDO   album  2025-05-15  1HEwEN64NjgTaHmo7LfkX8
# 1     False      Ordinary  single  2025-02-07  6qqrTXSdwiJaq8SO0X2lSe
# 2     False  6 DE FEBRERO  single  2025-05-05  2TCUMmklsJTLWHnoU4mSQ4
# 3     False    blackout 🧊  single  2025-03-25  2efbgTtEGNpsUZaOfgRTR6
# 4     False          APT.  single  2024-10-18  5vNRhkKd0yEAg8suGBpjeY
#
#                 artist_id                list
# 0  7a0XAaPaK2aDSqa8p3QnC7  Los 40 Principales
# 1  0fTSzq9jAh4c36UVb4V7CB  Los 40 Principales
# 2  7eLcDZDYHXZCebtQmVFL25  Los 40 Principales
# 3  0AqlFI0tz2DsEoJlKSIiT9  Los 40 Principales
# 4  3eVa5w3URK5duf6eyVDbu9  Los 40 Principales

# %%
# CAMBIAMOS MILISEGUNDOS A MINUTOS Y SEGUNDOS

# %%
df["relase_date"] = pd.to_datetime(df["relase_date"], format='mixed')

# %%
# Creamos lista vacia
duracion = []

for duracion_en_milisegundos in df["duration_ms"]:
    minutos = duracion_en_milisegundos // 60000  #1min = 60000 ms
    segundos = (duracion_en_milisegundos % 60000) // 1000  
    tiempo_cambiado = str(minutos) + ":" + str(segundos).zfill(2)  
    duracion.append(tiempo_cambiado)

# %%
df["duracion_mins_segs"] = duracion

# %%
print(df[["duration_ms", "duracion_mins_segs"]].head())
# Out:
#    duration_ms duracion_mins_segs
# 0       158036               2:38
# 1       186964               3:06
# 2       175584               2:55
# 3       182282               3:02
# 4       169917               2:49

# %%
# Cambiar fechas

# %%
# Mirar que tipo tienen
print(df["relase_date"].head())
# Out:
# 0   2025-05-15
# 1   2025-02-07
# 2   2025-05-05
# 3   2025-03-25
# 4   2024-10-18
# Name: relase_date, dtype: datetime64[ns]

# %%
# Cambiar a datetime64
df["relase_date"] = pd.to_datetime(df["relase_date"])

# %%
# Vemos los cambios
print(df["relase_date"].dtypes)
print(df["relase_date"].head())
# Out:
# datetime64[ns]
# 0   2025-05-15
# 1   2025-02-07
# 2   2025-05-05
# 3   2025-03-25
# 4   2024-10-18
# Name: relase_date, dtype: datetime64[ns]

# %%
# Cambiar los | por comas en los feats

# %%
df["track_name"]=df["track_name"].map(lambda x : x.lower())
genres=[]
for genre in df['artist_genres']:
    genres.append(str(genre).split("|"))

df['artist_genres'] = genres

# %%
df['feats']=df['feats'].str.replace("|",", ")

# %%
print(df.head())
# Out:
#    top        track_name  track_popularity  duration_ms  artist_name  \
# 0    1  no tiene sentido                93       158036        Beéle
# 1    2          ordinary                96       186964  Alex Warren
# 2    3      6 de febrero                75       175584       Aitana
# 3    4        blackout 🧊                84       182282       Emilia
# 4    5              apt.                94       169917         ROSÉ
#
#                               artist_genres  artist_popularity  \
# 0  [latin afrobeats, reggaeton, pop urbano]                 93
# 1                                     [nan]                 90
# 2                                     [nan]                 80
# 3                          [argentine trap]                 80
# 4                                   [k-pop]                 85
#
#                 feats  explicit         album    type relase_date  \
# 0                 NaN     False       BORONDO   album  2025-05-15
# 1                 NaN     False      Ordinary  single  2025-02-07
# 2                 NaN     False  6 DE FEBRERO  single  2025-05-05
# 3  TINI, Nicki Nicole     False    blackout 🧊  single  2025-03-25
# 4          Bruno Mars     False          APT.  single  2024-10-18
#
#                  track_id               artist_id                list  \
# 0  1HEwEN64NjgTaHmo7LfkX8  7a0XAaPaK2aDSqa8p3QnC7  Los 40 Principales
# 1  6qqrTXSdwiJaq8SO0X2lSe  0fTSzq9jAh4c36UVb4V7CB  Los 40 Principales
# 2  2TCUMmklsJTLWHnoU4mSQ4  7eLcDZDYHXZCebtQmVFL25  Los 40 Principales
# 3  2efbgTtEGNpsUZaOfgRTR6  0AqlFI0tz2DsEoJlKSIiT9  Los 40 Principales
# 4  5vNRhkKd0yEAg8suGBpjeY  3eVa5w3URK5duf6eyVDbu9  Los 40 Principales
#
#   duracion_mins_segs
# 0               2:38
# 1               3:06
# 2               2:55
# 3               3:02
# 4               2:49

# %%
# CAMBIAMOS LOS NOMBRES

# %%
p=['(with','(feat']
for i in p:
    for x in range(len(df)):
        cancion=df.loc[x,'track_name']
        if i in cancion:
            df.loc[x,'track_name']=str(cancion).split('(')[0]

# %%
df_exploded=df.explode('artist_genres')
df_exploded
# Out:
#      top                   track_name  track_popularity  duration_ms  \
# 0      1             no tiene sentido                93       158036
# 0      1             no tiene sentido                93       158036
# 0      1             no tiene sentido                93       158036
# 1      2                     ordinary                96       186964
# 2      3                 6 de febrero                75       175584
# ..   ...                          ...               ...          ...
# 369   96  better off (alone, pt. iii)                77       151702
# 370   97             won't forget you                55       398663
# 371   98                      desire                 74       179161
# 372   99             one in a million                68       160529
# 373  100                         apt.                94       169917
#
#        artist_name    artist_genres  artist_popularity                  feats  \
# 0            Beéle  latin afrobeats                 93                    NaN
# 0            Beéle        reggaeton                 93                    NaN
# 0            Beéle       pop urbano                 93                    NaN
# 1      Alex Warren              nan                 90                    NaN
# 2           Aitana              nan                 80                    NaN
# ..             ...              ...                ...                    ...
# 369    Alan Walker              nan                 82  Dash Berlin, Vikkstar
# 370         Shouse              nan                 69                    NaN
# 371  Calvin Harris              edm                 90              Sam Smith
# 372     Bebe Rexha              nan                 80           David Guetta
# 373           ROSÉ            k-pop                 85             Bruno Mars
#
#      explicit                    album    type relase_date  \
# 0       False                  BORONDO   album  2025-05-15
# 0       False                  BORONDO   album  2025-05-15
# 0       False                  BORONDO   album  2025-05-15
# 1       False                 Ordinary  single  2025-02-07
# 2       False             6 DE FEBRERO  single  2025-05-05
# ..        ...                      ...     ...         ...
# 369     False              Walkerworld   album  2023-11-10
# 370     False         Won't Forget You  single  2022-02-04
# 371     False  Desire (with Sam Smith)  single  2023-07-28
# 372     False         One in a Million  single  2023-08-04
# 373     False                     APT.  single  2024-10-18
#
#                    track_id               artist_id                list  \
# 0    1HEwEN64NjgTaHmo7LfkX8  7a0XAaPaK2aDSqa8p3QnC7  Los 40 Principales
# 0    1HEwEN64NjgTaHmo7LfkX8  7a0XAaPaK2aDSqa8p3QnC7  Los 40 Principales
# 0    1HEwEN64NjgTaHmo7LfkX8  7a0XAaPaK2aDSqa8p3QnC7  Los 40 Principales
# 1    6qqrTXSdwiJaq8SO0X2lSe  0fTSzq9jAh4c36UVb4V7CB  Los 40 Principales
# 2    2TCUMmklsJTLWHnoU4mSQ4  7eLcDZDYHXZCebtQmVFL25  Los 40 Principales
# ..                      ...                     ...                 ...
# 369  0SML6wWerD0yI2Xd4OUC1R  7vk5e3vY1uw9plTHJAMwjN      Shazam Top 200
# 370  08DprFlcwlc5zny9ErPkHG  2TcGJdSOiOvITBzhvfX8XB      Shazam Top 200
# 371  22dUzMFttcR3uU17NcOAIv  7CajNmpbOovFoOoasH2HaY      Shazam Top 200
# 372  3YfGTvsTAWGC2lgoDOikUz  64M6ah0SkkRsnPGtGiRAbb      Shazam Top 200
# 373  5vNRhkKd0yEAg8suGBpjeY  3eVa5w3URK5duf6eyVDbu9      Shazam Top 200
#
#     duracion_mins_segs
# 0                 2:38
# 0                 2:38
# 0                 2:38
# 1                 3:06
# 2                 2:55
# ..                 ...
# 369               2:31
# 370               6:38
# 371               2:59
# 372               2:40
# 373               2:49
#
# [526 rows x 16 columns]

# %%
# Guardar DataFrame
df.to_csv("df_trans.csv", index=False, encoding='utf-8')
print("CSV exportado")
df_exploded.to_csv("genres_exploded.csv", index=False, encoding='utf-8')
print("CSV exportado")
# Out:
# CSV exportado
# CSV exportado
